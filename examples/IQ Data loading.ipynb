# %% [markdown]
# # Loading of IQ data

# %%
from pyiconeus import open_path
from matplotlib import pyplot as plt

# %% [markdown]
# # Open the example (with default values: blocksStart=1, blockEnd=1)

# %%
raw = open_path("../tests/data/2DScan_v2.raw", "../tests/data/2DScan_v2.hraw")

# %% [markdown]
# # Shape of a block

# %%
raw.data.shape
# Out:
# (91, 128, 400)

# %% [markdown]
# # Total number of blocks

# %%
raw.metadata.numberOfBlock
# Out:
# 9

# %% [markdown]
# # Opening a range of block

# %%
raw = open_path("../tests/data/2DScan_v2.raw", "../tests/data/2DScan_v2.hraw", 5, 9)

# %%
raw.data.shape
# Out:
# (91, 128, 400, 5)

# %% [markdown]
# # Error raised when blockStart > blockEnd

# %%
raw = open_path("../tests/data/2DScan_v2.raw", "../tests/data/2DScan_v2.hraw", 510, 9)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 raw = open_path("../tests/data/2DScan_v2.raw", "../tests/data/2DScan_v2.hraw", 510, 9)
#
# File ~\Documents\Code\PyIconeus\src\pyiconeus\io\base.py:109, in open_path(path, path2, blockStart, blockEnd)
#     104 if path2 is not None and not os.path.isfile(path2):
#     105     raise FileNotFoundError(
#     106         2, "The following file does not exist", path2
#     107     )
# --> 109 return dispatch_extension(path, path2, blockStart, blockEnd)
#
# File ~\Documents\Code\PyIconeus\src\pyiconeus\io\base.py:69, in dispatch_extension(filepath, fileheader, blockStart, blockEnd)
#      67     if not fileheader.endswith(".hraw"):
#      68         raise ValueError(f"fileheader {fileheader!r} must end with .hraw for a .raw file")
# ---> 69     return read_raw(filepath, fileheader, blockStart, blockEnd)
#      70 else:
#      71     raise ValueError(f"Unsupported file extension for {filepath!r}")
#
# File ~\Documents\Code\PyIconeus\src\pyiconeus\io\base.py:51, in read_raw(filepath, fileheader, blockStart, blockEnd)
#      50 def read_raw(filepath: str, fileheader: str, blockStart: int = 1, blockEnd: int = 1) -> Raw:
# ---> 51     return Raw(filepath, fileheader, blockStart, blockEnd)
#
# File ~\Documents\Code\PyIconeus\src\pyiconeus\models\Raw.py:103, in Raw.__init__(self, filepath, file_header, blockStart, blockEnd)
#     101     f.seek(sizeToSkip, 1)
#     102 if blockEnd < blockStart:
# --> 103     raise RuntimeError("blockEnd must be greater or equal to blockStart")
#     104 if (blockEnd > self.metadata.numberOfBlock):
#     105     warnings.warn(RuntimeWarning("Raw init", "Passed blockEnd argument was greater than the total number of block. Automatically set to numberOfBlock"))
#
# RuntimeError: blockEnd must be greater or equal to blockStart

# %% [markdown]
# # Warning when blockEnd > numberOfBlock

# %%
raw = open_path("../tests/data/2DScan_v2.raw", "../tests/data/2DScan_v2.hraw", 1, 11)
# Out:
# C:\Users\simon.campredon\Documents\Code\PyIconeus\src\pyiconeus\models\Raw.py:105: RuntimeWarning: ('Raw init', 'Passed blockEnd argument was greater than the total number of block. Automatically set to numberOfBlock')
#   warnings.warn(RuntimeWarning("Raw init", "Passed blockEnd argument was greater than the total number of block. Automatically set to numberOfBlock"))

# %%
raw.data.shape
# Out:
# (91, 128, 400, 9)

# %%
raw = open_path("../tests/data/2DScan_v2.raw", "../tests/data/2DScan_v2.hraw", 1, 1)

# %%
import numpy as np

# %%
raw.data = np.mean(np.absolute(raw.data[:, :, :]), axis=2)

# %%
fig, ax = plt.subplots()

im = ax.imshow(raw.data, cmap='gray')
