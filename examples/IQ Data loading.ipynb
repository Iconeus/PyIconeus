# %% [markdown]
# # Loading of IQ data

# %%
from pyiconeus import open_path

# %%
raw = open_path("../tests/data/TestULM2D_v2.raw", "../tests/data/TestULM2D_v2.hraw")

# %%
raw.data.shape

# %%
raw.metadata.numberOfBlock

# %%
raw = open_path("../tests/data/TestULM2D_v2.raw", "../tests/data/TestULM2D_v2.hraw", 5, 9)

# %%
raw.data.shape

# %%
raw = open_path("../tests/data/TestULM2D_v2.raw", "../tests/data/TestULM2D_v2.hraw", 510, 9)

# %%
raw = open_path("../tests/data/TestULM2D_v2.raw", "../tests/data/TestULM2D_v2.hraw", 1, 10)

# %%
raw.data.shape
